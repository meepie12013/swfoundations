# %% [markdown]
# # Welcome to Colab!
#
# If you're seeing this screen, congratulations - you've successfully accessed the demo workshop!
#
# Your next step from here is to click on **File > Save a Copy in Drive** from the toolbar at the top of the page.
#
# From there, you will be able to edit the document by yourself. This means that you can write your own code and run it.
#
# Go ahead and try to run the following code by pressing the "arrow" button inside the gray box below:

# %%
print("Welcome to UMBC!")
# Out:
# Welcome to UMBC!

# %% [markdown]
# If everything worked properly, you should see the same message inside the `print()` function displayed below the code cell.
#
# In the code cell below, modify the message with your own custom greeting, and try to run it. Type anything you want **between the quotation marks**. Do **not** remove the quotation marks, paranetheses, or `print`.

# %%
print(" hello  ")

# %% [markdown]
# Finally, use the instructions in your intro lecture handout to submit your practice workshop to the instructor. Clicking the "Share" button makes it incredibly hard to read the workshop as the screen darkens, so make sure you've done everything up to this point.
#
# It's important to go through this process before starting your first workshop so that you do not lose any of your work.
