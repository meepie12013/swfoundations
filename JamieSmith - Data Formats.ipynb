# %% [markdown]
# # Data Formats - Exercises

# %% [markdown]
# ### **Exercise - CSV**
# * Use your browser and go to https://www.kaggle.com/search.
# * Search for a topic of your choice and download a CSV file.
# * View the file in either Excel or Google Sheets.
# * Do you understand the data in the file?
# * For example, you can search for `baseball` and find many CSV files.

# %% [markdown]
# ### **Exercise - CSV**
# Using a text editor such as VS Code (or any other really) or Google Sheets, create a CSV file with at least 4 columns and 5 rows of data.
# **Be creative**.  By generating the data yourself, and creating a file that has meaning to you, it'll make it easier for you to understand exercises later in the week.
#
# You will save this file and use it later in the course.
#
# **QUESTION**.  Can you open this CSV file in Excel?

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1s2xSVVcQh3eWwOIL-EIbFlEj_Yw3Ur2J08BKLQomCIo/edit?usp=sharing

# %% [markdown]
# ### **Exercise - JSON**
# * Use your browser and go to http://api.open-notify.org/astros.json and view the result.
# * Do the same with http://api.open-notify.org/iss-now.json to see the location of the International Space Station.

# %% [markdown]
# ### **Exercise - JSON**
# * The following API endpoint will return valid XML or JSON of a random user.
# ** Paste the URL into your browser and simply note data that is in XML format:
# https://randomuser.me/api/?format=xml
# ** Paste the URL into your browser and simply note data that is in JSON format.
# https://randomuser.me/api/?format=json

# %% [markdown]
# ### **Exercise - JSON**
#
# What's the difference between these two JSON objects?
#
# ```
# {
#   "profile" : {
#     "name" : "Manuel Kraft",
#     "gender" : "male",
#     "married" : true
#   }
# }
# ```
#
# AND
#
# ```
# {
#   "profile" : {
#     "name" : "Manuel Kraft",
#     "gender" : "male",
#     "married" : "true"
#   }
# }
# ```

# %% [markdown]
# ### **Exercise - JSON**
# - Use your editor or Google Docs to compose a JSON Object that has the following attributes:
#   - `firstName`
#   - `lastName`
#   - `age`
#   - `address` --- This should be its own object with **3 member**: `streetAddress`, `street`, `zipcode`
#   - `ownsPet` (either true or false)
#   - An array of `hobbies`
# - Use [JSON Lint](https://jsonlint.com/) to check if it's valid JSON.

# %%
{
	"profile": {
		"firstName": "Jamie",
		"lastName": "Smith",
		"age": 25,
		"address": {
			"streetAddress": "1000",
			"street": "Hilltop Road",
			"zipcode": 21250
		},
		"ownsPet": true,
		"hobbies": ["design", "sleeping", "piano"]
	}
}

# %% [markdown]
# ### **Exercise - JSON**
# - Create a JSON formatted file of YOUR choice.
# You will use this data in an exercise later this week.
#   - What could you data contain?
#     - Useful information for other people to use.
#     - Useful information for you to use in an application.
#   - IDEAS: Dog or Cat breeds, Sports Team, Sports Stadiums, Plants data (maybe those in your house), List of useful websites, Occupations, Description of books in your personal library,etc.
#   - OTHER IDEAS?  Post in #general channel in Slack.
#   - NOTE.  Earlier you created a file formatted as CSV.  Can you rework that as JSON data?
# - Use [JSON Lint](https://jsonlint.com/) to check if it's valid JSON.

# %%
{
	"fonts": {
		"Akzidenz-Grotesk": {
			"fontFamily": "Akzidenz-Grotesk",
			"releaseDate": 1898,
			"Creator": "H. Berthold AG",
			"Serif": False,
			"Classification": "Grotesque",
			"Movement": ["Swiss Style", "International"]
		},
		"Garamond": {
			"fontFamily": "Garamond",
			"releaseDate": 1510,
			"Creator": "Claude Garamond",
			"Serif": True,
			"Classification": "Old-Style",
			"Movement": ["Late Renaissance"]
		},
		"Baskerville": {
			"fontFamily": "Baskerville",
			"releaseDate": 1754,
			"Creator": "John Baskerville",
			"Serif": True,
			"Classification": "Transitional",
			"Movement": ["Transitional", "Neo-Classical"]
		},
		"Fraktur": {
			"fontFamily": "Fraktur",
			"releaseDate": 1640,
			"Creator": "Johann Schönsperger",
			"Serif": False,
			"Classification": "Blackletter",
			"Movement": ["Gothic"]
		}
	}
}
